# %% [markdown]
# AI ML ASSIGNMENT 1
# (OVISHREE S
# 21BEC1692)

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# TASK 1 [CREATE A PANDAS DATA FRAME]

# %%
df = {'Candidates':['A','B','C','D','E','F','G','H','I','J','K'],'Scores':[98,76,88,69,57,98,73,90,89,56,74],'Age':[21,23,24,np.nan,24,22,np.nan,22,21,23,22],'Sex':['m','f','m','f','m','f','f','m','m','f','f'],
'Rank':[2,7,4,3,7,5,8,3,6,8,np.nan]}
df
# Out:
# {'Candidates': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K'],
#  'Scores': [98, 76, 88, 69, 57, 98, 73, 90, 89, 56, 74],
#  'Age': [21, 23, 24, nan, 24, 22, nan, 22, 21, 23, 22],
#  'Sex': ['m', 'f', 'm', 'f', 'm', 'f', 'f', 'm', 'm', 'f', 'f'],
#  'Rank': [2, 7, 4, 3, 7, 5, 8, 3, 6, 8, nan]}

# %%
df1=pd.DataFrame(df) ## CREATING DATA FRAME
df1
# Out:
#    Candidates  Scores   Age Sex  Rank
# 0           A      98  21.0   m   2.0
# 1           B      76  23.0   f   7.0
# 2           C      88  24.0   m   4.0
# 3           D      69   NaN   f   3.0
# 4           E      57  24.0   m   7.0
# 5           F      98  22.0   f   5.0
# 6           G      73   NaN   f   8.0
# 7           H      90  22.0   m   3.0
# 8           I      89  21.0   m   6.0
# 9           J      56  23.0   f   8.0
# 10          K      74  22.0   f   NaN

# %% [markdown]
# TASK 2 [ CHECK THE INFO ]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Candidates  11 non-null     object
#  1   Scores      11 non-null     int64
#  2   Age         9 non-null      float64
#  3   Sex         11 non-null     object
#  4   Rank        10 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 568.0+ bytes

# %% [markdown]
# TASK 3 [ CHECK THE DESCRIPTIVE STATISTICS ]

# %%
df1.describe() ## DESCRIPTIVE STATISTICS
# Out:
#           Scores        Age       Rank
# count  11.000000   9.000000  10.000000
# mean   78.909091  22.444444   5.300000
# std    14.855669   1.130388   2.213594
# min    56.000000  21.000000   2.000000
# 25%    71.000000  22.000000   3.250000
# 50%    76.000000  22.000000   5.500000
# 75%    89.500000  23.000000   7.000000
# max    98.000000  24.000000   8.000000

# %% [markdown]
# TASK 4 [ CHECK THE 4TH INDEX OBSERVATION ]

# %%
df1.loc[4] ## LOCATION
# Out:
# Candidates       E
# Scores          57
# Age           24.0
# Sex              m
# Rank           7.0
# Name: 4, dtype: object

# %% [markdown]
# TASK 5 [ CHECK THE NULL VALUES ]

# %%
df1.isnull().any() ### checking if there is any null value in our dataset
# Out:
# Candidates    False
# Scores        False
# Age            True
# Sex           False
# Rank           True
# dtype: bool
